# %% [markdown]
# # Introduction to Data Science – Homework 4
# *COMP 5360 / MATH 4100, University of Utah, http://datasciencecourse.net/*
#
# Due: Friday, February 10, 2023, 11:59pm.
#
# In this homework, you will study Salt Lake City air quality data and complete an A/B test comparing two ads.

# %% [markdown]
# ## Your Data
# Fill out the following information:
#
# *First Name:* Melissa
# *Last Name:* Frisby
# *E-mail:* u1175875@utah.edu
# *UID:* u1175875

# %%
# imports and setup 
import pandas as pd
import scipy as sc
from scipy.stats import norm

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 6)
plt.style.use('ggplot')

# %% [markdown]
# ## Part 1: SLC Air Quality Index
#
# In this problem, you'll study the Air Quality in Salt Lake City.
#
# ### Task 1.0.  Learn about AQI
#
# Read about the [air quality index (AQI)](https://airnow.gov/index.cfm?action=aqibasics.aqi) and the
# [AirNow](https://airnow.gov/index.cfm?action=topics.about_airnow) system.
#
#
# ### Task 1.1. Download data
# The EPA gives access to historical air quality data at the AirData website. Read about the data available on [this information page](https://www.epa.gov/outdoor-air-quality-data/air-data-basic-information).
#
#
# Go to [this website](https://www.epa.gov/outdoor-air-quality-data/download-daily-data) and download the following daily data:
# + Pollutant = PM2.5
# + Year = 2022
# + City = Salt Lake City, UT
# + Monitor Site = All Sites

# %% [markdown]
# ### Task 1.2. Import the data
# Use the pandas.read_csv() function to import the data
#
# A word of warning: this data isn't very clean:
#
# + The dates are not sorted.
# + Some dates may have missing values.
# + Some dates may have multiple values corresponding to different sensors (POC=1,2,3,4,5) and different sites.

# %%
# your code goes here
data = pd.read_csv('ad_viz_plotval_data.csv')
data.head()
# Out:
#        Date Source    Site ID  POC  Daily Mean PM2.5 Concentration     UNITS  \
# 0  1/1/2022    AQS  490352005    1                             4.3  ug/m3 LC
# 1  1/2/2022    AQS  490352005    1                             8.5  ug/m3 LC
# 2  1/3/2022    AQS  490352005    1                            16.5  ug/m3 LC
# 3  1/4/2022    AQS  490352005    1                             5.0  ug/m3 LC
# 4  1/5/2022    AQS  490352005    1                             5.2  ug/m3 LC
#
#    DAILY_AQI_VALUE    Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 0               18  Copper View                1               100
# 1               35  Copper View                1               100
# 2               60  Copper View                1               100
# 3               21  Copper View                1               100
# 4               22  Copper View                1               100
#
#    AQS_PARAMETER_CODE        AQS_PARAMETER_DESC  CBSA_CODE  \
# 0               88101  PM2.5 - Local Conditions      41620
# 1               88101  PM2.5 - Local Conditions      41620
# 2               88101  PM2.5 - Local Conditions      41620
# 3               88101  PM2.5 - Local Conditions      41620
# 4               88101  PM2.5 - Local Conditions      41620
#
#             CBSA_NAME  STATE_CODE STATE  COUNTY_CODE     COUNTY  \
# 0  Salt Lake City, UT          49  Utah           35  Salt Lake
# 1  Salt Lake City, UT          49  Utah           35  Salt Lake
# 2  Salt Lake City, UT          49  Utah           35  Salt Lake
# 3  Salt Lake City, UT          49  Utah           35  Salt Lake
# 4  Salt Lake City, UT          49  Utah           35  Salt Lake
#
#    SITE_LATITUDE  SITE_LONGITUDE
# 0      40.598056     -111.894167
# 1      40.598056     -111.894167
# 2      40.598056     -111.894167
# 3      40.598056     -111.894167
# 4      40.598056     -111.894167

# %% [markdown]
# ### Task 1.3. Plot the data
#
# 1. The data contains multiple PM2.5 concentration and AQI entries for the same date measured at different sites and with different sensors (POCS). Plot average PM2.5 and AQI values with respect to date in a single figure. Anyone analysing the graph should be able to answer, what is the average PM 2.5 concentration or the AQI value on a particular date.
#
# 2. Plot the average PM 2.5 concentration vs Date for two different sites (site ids - 490352005 and 490353016). Note in this case the average is just taken over POCs. Plot for both the sites should be in a single figure.
# *Hint*: use the pandas groupby function

# %%
# group by date
date = data.groupby('Date')
num_pm25 = date.count()
sum_pm25 = date.sum()
avg_pm25 = sum_pm25['Daily Mean PM2.5 Concentration']/num_pm25['Daily Mean PM2.5 Concentration']
avg_aqi = sum_pm25['DAILY_AQI_VALUE']/num_pm25['DAILY_AQI_VALUE']

# group by site
site = data.groupby('Site ID')
num_site = site.count()
sum_site = site.sum()
avg_pm25_site = sum_site['Daily Mean PM2.5 Concentration']/num_site['Daily Mean PM2.5 Concentration']

plt.plot(avg_pm25, label = 'PM2.5 Concentration')
plt.plot(avg_aqi, label = 'AQI')
plt.title('PM2.5 Concentration and AQI by Day')
plt.xlabel('Date')
plt.ylabel('Concentration or Index')
plt.legend()
plt.show()

plt.plot(avg_pm25_site, label = 'Site 490352005')
plt.plot(avg_pm25_site, label = 'Site 490353016')
plt.title('PM2.5 Concentration Based on Site')
plt.xlabel('Date')
plt.ylabel('Concentration')
plt.legend()
plt.show()
# Out:
#           Date Source    Site ID  POC  Daily Mean PM2.5 Concentration  \
# 0     1/1/2022    AQS  490352005    1                             4.3
# 1     1/2/2022    AQS  490352005    1                             8.5
# 2     1/3/2022    AQS  490352005    1                            16.5
# 3     1/4/2022    AQS  490352005    1                             5.0
# 4     1/5/2022    AQS  490352005    1                             5.2
# 718   1/1/2022    AQS  490353006    1                             3.6
# 719   1/2/2022    AQS  490353006    1                             8.6
# 720   1/3/2022    AQS  490353006    1                            15.4
# 721   1/4/2022    AQS  490353006    1                             5.6
# 722   1/5/2022    AQS  490353006    1                             4.7
# 1768  1/1/2022    AQS  490353010    1                             2.9
# 1769  1/2/2022    AQS  490353010    1                             8.5
# 1770  1/3/2022    AQS  490353010    1                            16.7
# 1771  1/4/2022    AQS  490353010    1                             4.3
# 1772  1/5/2022    AQS  490353010    1                             3.8
# 2844  1/1/2022    AQS  490353013    2                             1.0
# 2845  1/2/2022    AQS  490353013    2                             2.8
# 2846  1/3/2022    AQS  490353013    2                             1.1
# 2847  1/4/2022    AQS  490353013    2                             4.2
# 2848  1/5/2022    AQS  490353013    2                             2.1
# 3558  1/1/2022    AQS  490353014    1                             4.7
# 3559  1/2/2022    AQS  490353014    1                             8.9
# 3560  1/3/2022    AQS  490353014    1                            17.5
# 3561  1/4/2022    AQS  490353014    1                             6.0
# 3562  1/5/2022    AQS  490353014    1                             5.1
# 4005  1/1/2022    AQS  490353015    1                             4.0
# 4006  1/2/2022    AQS  490353015    1                             8.5
# 4007  1/3/2022    AQS  490353015    1                            18.9
# 4008  1/4/2022    AQS  490353015    1                             4.6
# 4009  1/5/2022    AQS  490353015    1                             5.0
# 4718  1/1/2022    AQS  490353016    1                             2.6
# 4719  1/2/2022    AQS  490353016    1                             7.5
# 4720  1/3/2022    AQS  490353016    1                            16.9
# 4721  1/4/2022    AQS  490353016    1                             6.1
# 4722  1/5/2022    AQS  490353016    1                             3.4
# 5072  1/1/2022    AQS  490354002    1                             7.4
# 5073  1/2/2022    AQS  490354002    1                            10.4
# 5074  1/3/2022    AQS  490354002    1                            19.6
# 5075  1/4/2022    AQS  490354002    1                             5.4
# 5076  1/5/2022    AQS  490354002    1                             9.1
# 5792  1/1/2022    AQS  490450004    1                             5.2
# 5793  1/2/2022    AQS  490450004    1                             3.6
# 5794  1/3/2022    AQS  490450004    1                            12.2
# 5795  1/4/2022    AQS  490450004    1                             3.5
# 5796  1/5/2022    AQS  490450004    1                             2.0
#
#          UNITS  DAILY_AQI_VALUE              Site Name  DAILY_OBS_COUNT  \
# 0     ug/m3 LC               18            Copper View                1
# 1     ug/m3 LC               35            Copper View                1
# 2     ug/m3 LC               60            Copper View                1
# 3     ug/m3 LC               21            Copper View                1
# 4     ug/m3 LC               22            Copper View                1
# 718   ug/m3 LC               15              Hawthorne                1
# 719   ug/m3 LC               36              Hawthorne                1
# 720   ug/m3 LC               58              Hawthorne                1
# 721   ug/m3 LC               23              Hawthorne                1
# 722   ug/m3 LC               20              Hawthorne                1
# 1768  ug/m3 LC               12              ROSE PARK                1
# 1769  ug/m3 LC               35              ROSE PARK                1
# 1770  ug/m3 LC               61              ROSE PARK                1
# 1771  ug/m3 LC               18              ROSE PARK                1
# 1772  ug/m3 LC               16              ROSE PARK                1
# 2844  ug/m3 LC                4            Herriman #3                1
# 2845  ug/m3 LC               12            Herriman #3                1
# 2846  ug/m3 LC                5            Herriman #3                1
# 2847  ug/m3 LC               18            Herriman #3                1
# 2848  ug/m3 LC                9            Herriman #3                1
# 3558  ug/m3 LC               20              Lake Park                1
# 3559  ug/m3 LC               37              Lake Park                1
# 3560  ug/m3 LC               62              Lake Park                1
# 3561  ug/m3 LC               25              Lake Park                1
# 3562  ug/m3 LC               21              Lake Park                1
# 4005  ug/m3 LC               17  Utah Technical Center                1
# 4006  ug/m3 LC               35  Utah Technical Center                1
# 4007  ug/m3 LC               65  Utah Technical Center                1
# 4008  ug/m3 LC               19  Utah Technical Center                1
# 4009  ug/m3 LC               21  Utah Technical Center                1
# 4718  ug/m3 LC               11              Hawthorne                1
# 4719  ug/m3 LC               31              Hawthorne                1
# 4720  ug/m3 LC               61              Hawthorne                1
# 4721  ug/m3 LC               25              Hawthorne                1
# 4722  ug/m3 LC               14              Hawthorne                1
# 5072  ug/m3 LC               31              Near Road                1
# 5073  ug/m3 LC               43              Near Road                1
# 5074  ug/m3 LC               67              Near Road                1
# 5075  ug/m3 LC               23              Near Road                1
# 5076  ug/m3 LC               38              Near Road                1
# 5792  ug/m3 LC               22                   Erda                1
# 5793  ug/m3 LC               15                   Erda                1
# 5794  ug/m3 LC               51                   Erda                1
# 5795  ug/m3 LC               15                   Erda                1
# 5796  ug/m3 LC                8                   Erda                1
#
#       PERCENT_COMPLETE  AQS_PARAMETER_CODE  \
# 0                  100               88101
# 1                  100               88101
# 2                  100               88101
# 3                  100               88101
# 4                  100               88101
# 718                100               88101
# 719                100               88101
# 720                100               88101
# 721                100               88101
# 722                100               88101
# 1768               100               88101
# 1769               100               88101
# 1770               100               88101
# 1771               100               88101
# 1772               100               88101
# 2844               100               88101
# 2845               100               88101
# 2846               100               88101
# 2847               100               88101
# 2848               100               88101
# 3558               100               88502
# 3559               100               88502
# 3560               100               88502
# 3561               100               88502
# 3562               100               88502
# 4005               100               88101
# 4006               100               88101
# 4007               100               88101
# 4008               100               88101
# 4009               100               88101
# 4718               100               88101
# 4719               100               88101
# 4720               100               88101
# 4721               100               88101
# 4722               100               88101
# 5072               100               88101
# 5073               100               88101
# 5074               100               88101
# 5075               100               88101
# 5076               100               88101
# 5792               100               88101
# 5793               100               88101
# 5794               100               88101
# 5795               100               88101
# 5796               100               88101
#
#                           AQS_PARAMETER_DESC  CBSA_CODE           CBSA_NAME  \
# 0                   PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 1                   PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 2                   PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 3                   PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 4                   PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 718                 PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 719                 PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 720                 PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 721                 PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 722                 PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 1768                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 1769                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 1770                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 1771                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 1772                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 2844                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 2845                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 2846                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 2847                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 2848                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 3558  Acceptable PM2.5 AQI & Speciation Mass      41620  Salt Lake City, UT
# 3559  Acceptable PM2.5 AQI & Speciation Mass      41620  Salt Lake City, UT
# 3560  Acceptable PM2.5 AQI & Speciation Mass      41620  Salt Lake City, UT
# 3561  Acceptable PM2.5 AQI & Speciation Mass      41620  Salt Lake City, UT
# 3562  Acceptable PM2.5 AQI & Speciation Mass      41620  Salt Lake City, UT
# 4005                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 4006                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 4007                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 4008                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 4009                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 4718                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 4719                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 4720                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 4721                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 4722                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 5072                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 5073                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 5074                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 5075                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 5076                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 5792                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 5793                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 5794                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 5795                PM2.5 - Local Conditions      41620  Salt Lake City, UT
# 5796                PM2.5 - Local Conditions      41620  Salt Lake City, UT
#
#       STATE_CODE STATE  COUNTY_CODE     COUNTY  SITE_LATITUDE  SITE_LONGITUDE
# 0             49  Utah           35  Salt Lake      40.598056     -111.894167
# 1             49  Utah           35  Salt Lake      40.598056     -111.894167
# 2             49  Utah           35  Salt Lake      40.598056     -111.894167
# 3             49  Utah           35  Salt Lake      40.598056     -111.894167
# 4             49  Utah           35  Salt Lake      40.598056     -111.894167
# 718           49  Utah           35  Salt Lake      40.736389     -111.872222
# 719           49  Utah           35  Salt Lake      40.736389     -111.872222
# 720           49  Utah           35  Salt Lake      40.736389     -111.872222
# 721           49  Utah           35  Salt Lake      40.736389     -111.872222
# 722           49  Utah           35  Salt Lake      40.736389     -111.872222
# 1768          49  Utah           35  Salt Lake      40.784220     -111.931000
# 1769          49  Utah           35  Salt Lake      40.784220     -111.931000
# 1770          49  Utah           35  Salt Lake      40.784220     -111.931000
# 1771          49  Utah           35  Salt Lake      40.784220     -111.931000
# 1772          49  Utah           35  Salt Lake      40.784220     -111.931000
# 2844          49  Utah           35  Salt Lake      40.496392     -112.036298
# 2845          49  Utah           35  Salt Lake      40.496392     -112.036298
# 2846          49  Utah           35  Salt Lake      40.496392     -112.036298
# 2847          49  Utah           35  Salt Lake      40.496392     -112.036298
# 2848          49  Utah           35  Salt Lake      40.496392     -112.036298
# 3558          49  Utah           35  Salt Lake      40.709762     -112.008760
# 3559          49  Utah           35  Salt Lake      40.709762     -112.008760
# 3560          49  Utah           35  Salt Lake      40.709762     -112.008760
# 3561          49  Utah           35  Salt Lake      40.709762     -112.008760
# 3562          49  Utah           35  Salt Lake      40.709762     -112.008760
# 4005          49  Utah           35  Salt Lake      40.777145     -111.945849
# 4006          49  Utah           35  Salt Lake      40.777145     -111.945849
# 4007          49  Utah           35  Salt Lake      40.777145     -111.945849
# 4008          49  Utah           35  Salt Lake      40.777145     -111.945849
# 4009          49  Utah           35  Salt Lake      40.777145     -111.945849
# 4718          49  Utah           35  Salt Lake      40.807897     -112.087717
# 4719          49  Utah           35  Salt Lake      40.807897     -112.087717
# 4720          49  Utah           35  Salt Lake      40.807897     -112.087717
# 4721          49  Utah           35  Salt Lake      40.807897     -112.087717
# 4722          49  Utah           35  Salt Lake      40.807897     -112.087717
# 5072          49  Utah           35  Salt Lake      40.662878     -111.901188
# 5073          49  Utah           35  Salt Lake      40.662878     -111.901188
# 5074          49  Utah           35  Salt Lake      40.662878     -111.901188
# 5075          49  Utah           35  Salt Lake      40.662878     -111.901188
# 5076          49  Utah           35  Salt Lake      40.662878     -111.901188
# 5792          49  Utah           45     Tooele      40.600532     -112.353414
# 5793          49  Utah           45     Tooele      40.600532     -112.353414
# 5794          49  Utah           45     Tooele      40.600532     -112.353414
# 5795          49  Utah           45     Tooele      40.600532     -112.353414
# 5796          49  Utah           45     Tooele      40.600532     -112.353414

# %% [markdown]
# ### Task 1.4. Plot a moving average
#
# Make a plot with both the daily AQI value and a moving average for the daily AQI value. Use the daily AQI value that is averaged over the sites and POC. Experiment with different time windows to find one that is reasonable.
#
# *Hint:* Use the rolling() function as in Lecture 8.

# %%
# your code goes here
mov_avg_aqi = date['DAILY_AQI_VALUE'].rolling(window = 2, center = False)

plt.plot(avg_aqi)

# %% [markdown]
# ## Part 2: A/B testing
#
# First read the WIRED article on A/B testing [here](http://www.wired.com/2012/04/ff_abtesting/).
#
# Suppose your company is developing a new logo. The art department develops two logos: ‘Logo A’ and ‘Logo B’, shown below.
# ![](http://www.wired.com/wiredenterprise/wp-content/gallery/20-05/ff_abtesting_f.jpg)
# Your job is to figure out which logo is better.
#
#
# You decide to conduct the following experiment. You use Google ads to buy 6000 advertisements. In $N_A=3000$ of the ads (randomly chosen), you use Logo A and in the other $N_B=3000$ ads, you use Logo B. Then you see which logo attracts more clicks.
#
# It turns out that $n_A=800$ Logo A viewers click on the ad while $n_B=1000$ Logo B viewers click on the ad. Obviously Logo B did better in this test, but is the difference *significant* enough to say that Logo B is better? Or, perhaps, Logo B just got lucky in this test?
#
# The goal of this exercise will be to conduct a two-proportion z-test to determine if Logo B is better. The steps will be similar to those from Lecture 7 used for the 1954 Salk polio-vaccine experiment.

# %% [markdown]
# ### Task 2.1.  Formulate null hypothesis
#
# Let $p_A = n_A/N_A$ be the proportion of clicks on Logo A and similiarly $p_B$ be the proportion of clicks on Logo B. In terms of $p_A$ and $p_B$, clearly state the null and alternative hypothesis.

# %% [markdown]
# **Your Solution:** TODO

# %% [markdown]
# ### Task 2.2.  Find the two-proportion z-value
#
# Assuming the null hypothesis, we know from lecture that the test statistic, called the *two-proportion z-value*,
# $$
# Z = \frac{p_A - p_B}{\sqrt{\hat{p} \hat{q} \left( \frac{1}{N_A} + \frac{1}{N_B} \right)}}.
# $$
# is approximately  distributed according to the standard normal distribution. Here $\hat{p} = \frac{N_A}{N_A + N_B}p_A + \frac{N_B}{N_A + N_B}p_B$ and $\hat{q} = 1-\hat{p}$.
#
#
# Find the two-proportion z-value.

# %%
# your code goes here

# %% [markdown]
# ### Task 2.3. Complete the two proportion z-test
#
# Find the $p$-value for the hypothesis test. Do this first using the normal cdf function and then check your answer by running a two proportions z-test in python with the proportions_ztest function.

# %%
# your code goes here

# %% [markdown]
# ### Task 2.4. Interpretation
#
# Interpret the $p$-value in this example and  state the result of the hypothesis test at the $\alpha=10\%$ and $\alpha=5\%$ significance levels.

# %% [markdown]
# **Your Interpretation:** TODO
